# %%
import numpy as np
import pandas as pd

# %%
d1={'name':['Mayura','Gopala','Mouli','Chandra','Maraja','Suraja','Raaja','Mani','Kumaara','Ayyappu'],
    'age':[5,6,7,8,9,3,4,20,23,17],
    'class':['1st','2nd','3rd','4th','5th','LKG','UKG','BE','MCA','BCA'],
    'marks':[70,40,30,80,75,40,21,99,10,80 ]
    }

# %%
d1
# Out:
# {'name': ['Mayura',
#   'Gopala',
#   'Mouli',
#   'Chandra',
#   'Maraja',
#   'Suraja',
#   'Raaja',
#   'Mani',
#   'Kumaara',
#   'Ayyappu'],
#  'age': [5, 6, 7, 8, 9, 3, 4, 20, 23, 17],
#  'class': ['1st',
#   '2nd',
#   '3rd',
#   '4th',
#   '5th',
#   'LKG',
#   'UKG',
#   'BE',
#   'MCA',
#   'BCA'],
#  'marks': [70, 40, 30, 80, 75, 40, 21, 99, 10, 80]}

# %%
df=pd.DataFrame(d1)
df
# Out:
#       name  age class  marks
# 0   Mayura    5   1st     70
# 1   Gopala    6   2nd     40
# 2    Mouli    7   3rd     30
# 3  Chandra    8   4th     80
# 4   Maraja    9   5th     75
# 5   Suraja    3   LKG     40
# 6    Raaja    4   UKG     21
# 7     Mani   20    BE     99
# 8  Kumaara   23   MCA     10
# 9  Ayyappu   17   BCA     80

# %%
df['name']
# Out:
# 0     Mayura
# 1     Gopala
# 2      Mouli
# 3    Chandra
# 4     Maraja
# 5     Suraja
# 6      Raaja
# 7       Mani
# 8    Kumaara
# 9    Ayyappu
# Name: name, dtype: object

# %%
df.head()
# Out:
#       name  age class  marks
# 0   Mayura    5   1st     70
# 1   Gopala    6   2nd     40
# 2    Mouli    7   3rd     30
# 3  Chandra    8   4th     80
# 4   Maraja    9   5th     75

# %%
df.tail()
# Out:
#       name  age class  marks
# 5   Suraja    3   LKG     40
# 6    Raaja    4   UKG     21
# 7     Mani   20    BE     99
# 8  Kumaara   23   MCA     10
# 9  Ayyappu   17   BCA     80

# %%
df.head(2)
# Out:
#      name  age class  marks
# 0  Mayura    5   1st     70
# 1  Gopala    6   2nd     40

# %%
df.tail(6)
# Out:
#       name  age class  marks
# 4   Maraja    9   5th     75
# 5   Suraja    3   LKG     40
# 6    Raaja    4   UKG     21
# 7     Mani   20    BE     99
# 8  Kumaara   23   MCA     10
# 9  Ayyappu   17   BCA     80

# %%
df.to_csv('student.csv')

# %%
df.describe()
# Out:
#              age      marks
# count  10.000000  10.000000
# mean   10.200000  54.500000
# std     7.130529  29.934187
# min     3.000000  10.000000
# 25%     5.250000  32.500000
# 50%     7.500000  55.000000
# 75%    15.000000  78.750000
# max    23.000000  99.000000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# name     object
# age       int64
# class    object
# marks     int64
# dtype: object

# %%
newdf=df.copy()
newdf
# Out:
#       name  age class  marks
# 0   Mayura    5   1st     70
# 1   Gopala    6   2nd     40
# 2    Mouli    7   3rd     30
# 3  Chandra    8   4th     80
# 4   Maraja    9   5th     75
# 5   Suraja    3   LKG     40
# 6    Raaja    4   UKG     21
# 7     Mani   20    BE     99
# 8  Kumaara   23   MCA     10
# 9  Ayyappu   17   BCA     80

# %%
newdf.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# df.columns

# %%
df.T
# Out:
#             0       1      2        3       4       5      6     7        8  \
# name   Mayura  Gopala  Mouli  Chandra  Maraja  Suraja  Raaja  Mani  Kumaara
# age         5       6      7        8       9       3      4    20       23
# class     1st     2nd    3rd      4th     5th     LKG    UKG    BE      MCA
# marks      70      40     30       80      75      40     21    99       10
#
#              9
# name   Ayyappu
# age         17
# class      BCA
# marks       80

# %%
df.columns
# Out:
# Index(['name', 'age', 'class', 'marks'], dtype='object')

# %%
df.sort_index()
# Out:
#       name  age class  marks
# 0   Mayura    5   1st     70
# 1   Gopala    6   2nd     40
# 2    Mouli    7   3rd     30
# 3  Chandra    8   4th     80
# 4   Maraja    9   5th     75
# 5   Suraja    3   LKG     40
# 6    Raaja    4   UKG     21
# 7     Mani   20    BE     99
# 8  Kumaara   23   MCA     10
# 9  Ayyappu   17   BCA     80

# %%
df.sort_index(ascending=False)
# Out:
#       name  age class  marks
# 9  Ayyappu   17   BCA     80
# 8  Kumaara   23   MCA     10
# 7     Mani   20    BE     99
# 6    Raaja    4   UKG     21
# 5   Suraja    3   LKG     40
# 4   Maraja    9   5th     75
# 3  Chandra    8   4th     80
# 2    Mouli    7   3rd     30
# 1   Gopala    6   2nd     40
# 0   Mayura    5   1st     70

# %%
df
# Out:
#       name  age class  marks
# 0   Mayura    5   1st     70
# 1   Gopala    6   2nd     40
# 2    Mouli    7   3rd     30
# 3  Chandra    8   4th     80
# 4   Maraja    9   5th     75
# 5   Suraja    3   LKG     40
# 6    Raaja    4   UKG     21
# 7     Mani   20    BE     99
# 8  Kumaara   23   MCA     10
# 9  Ayyappu   17   BCA     80

# %%
df.loc[-1,"Empname"]="Record"
df
# Out:
#        name   age class  marks Empname
#  0   Mayura   5.0   1st   70.0  Record
#  1   Gopala   6.0   2nd   40.0     NaN
#  2    Mouli   7.0   3rd   30.0     NaN
#  3  Chandra   8.0   4th   80.0     NaN
#  4   Maraja   9.0   5th   75.0     NaN
#  5   Suraja   3.0   LKG   40.0     NaN
#  6    Raaja   4.0   UKG   21.0     NaN
#  7     Mani  20.0    BE   99.0     NaN
#  8  Kumaara  23.0   MCA   10.0     NaN
#  9  Ayyappu  17.0   BCA   80.0     NaN
# -1      NaN   NaN   NaN    NaN  Record

# %%
df.loc[0,"Empname"]="Record"
df
# Out:
#        name   age class  marks Empname
#  0   Mayura   5.0   1st   70.0  Record
#  1   Gopala   6.0   2nd   40.0     NaN
#  2    Mouli   7.0   3rd   30.0     NaN
#  3  Chandra   8.0   4th   80.0     NaN
#  4   Maraja   9.0   5th   75.0     NaN
#  5   Suraja   3.0   LKG   40.0     NaN
#  6    Raaja   4.0   UKG   21.0     NaN
#  7     Mani  20.0    BE   99.0     NaN
#  8  Kumaara  23.0   MCA   10.0     NaN
#  9  Ayyappu  17.0   BCA   80.0     NaN
# -1      NaN   NaN   NaN    NaN  Record

# %%
df
# Out:
#        name   age class  marks Empname
#  0   Mayura   5.0   1st   70.0  Record
#  1   Gopala   6.0   2nd   40.0     NaN
#  2    Mouli   7.0   3rd   30.0     NaN
#  3  Chandra   8.0   4th   80.0     NaN
#  4   Maraja   9.0   5th   75.0     NaN
#  5   Suraja   3.0   LKG   40.0     NaN
#  6    Raaja   4.0   UKG   21.0     NaN
#  7     Mani  20.0    BE   99.0     NaN
#  8  Kumaara  23.0   MCA   10.0     NaN
#  9  Ayyappu  17.0   BCA   80.0     NaN
# -1      NaN   NaN   NaN    NaN  Record

# %%
newdf
# Out:
#       name  age class  marks
# 0   Mayura    5   1st     70
# 1   Gopala    6   2nd     40
# 2    Mouli    7   3rd     30
# 3  Chandra    8   4th     80
# 4   Maraja    9   5th     75
# 5   Suraja    3   LKG     40
# 6    Raaja    4   UKG     21
# 7     Mani   20    BE     99
# 8  Kumaara   23   MCA     10
# 9  Ayyappu   17   BCA     80

# %%
secdf=newdf.copy()
secdf
# Out:
#       name  age class  marks
# 0   Mayura    5   1st     70
# 1   Gopala    6   2nd     40
# 2    Mouli    7   3rd     30
# 3  Chandra    8   4th     80
# 4   Maraja    9   5th     75
# 5   Suraja    3   LKG     40
# 6    Raaja    4   UKG     21
# 7     Mani   20    BE     99
# 8  Kumaara   23   MCA     10
# 9  Ayyappu   17   BCA     80
